# %%
nih_path = "/home/karan/Documents/BTP_Proj/Image_result/Nih/batch_0.pkl"
chexpert_path = "/home/karan/Documents/BTP_Proj/Image_result/Chexpert/batch_0.pkl"
vinbig_path = "/home/karan/Documents/BTP_Proj/Image_result/Vinbig/batch_0.pkl"

# %%
import pickle
with open(nih_path, 'rb') as f:
    data = pickle.load(f)

# %%
len(data[0][1])
# Out:
# 14

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the image as a NumPy array
fig = plt.figure()
image = data[1][0]
image = image.reshape(224,224,1)
# Convert the image to grayscale
# image = image[:, :, 0]

# Display the image
plt.imshow(image, cmap="gray")
plt.xticks([])
plt.yticks([])
fig.set_size_inches(3.28, 3.28)
plt.show()
fig.savefig("plot.pdf", bbox_inches="tight")
