# %%
# Create 3 lists: model_name, params, Multadds
model_name = ["ResNet", "DenseNet", "SqueezeNet", "MobileNet", "ShuffleNet", "MobileViT (Baseline)", "SqueezeViT (Ours)"]
params = [11.69, 7.98, 1.25, 3.50, 7.39, 0.95, 0.54]
Multadds = [1.81, 2.83, 0.83, 0.30, 0.58, 0.20, 0.37]

# Print the 3 lists
print("Model Name: ", model_name)
print("Params: ", params)
print("Multadds: ", Multadds)
# Out:
# Model Name:  ['ResNet', 'DenseNet', 'SqueezeNet', 'MobileNet', 'ShuffleNet', 'MobileViT (Baseline)', 'SqueezeViT (Ours)']
# Params:  [11.69, 7.98, 1.25, 3.5, 7.39, 0.95, 0.54]
# Multadds:  [1.81, 2.83, 0.83, 0.3, 0.58, 0.2, 0.37]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = np.array(["Model 1", "Model 2", "Model 3"])
y1 = np.array([0.9, 0.85, 0.92])
y2 = np.array([0.88, 0.9, 0.86])
y3 = np.array([0.95, 0.91, 0.93])

# Create line plot
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label="Dataset 1")
plt.plot(x, y2, label="Dataset 2")
plt.plot(x, y3, label="Dataset 3")

# Add labels and title
plt.xlabel("Model")
plt.ylabel("AUROC Score")
# plt.title("AUROC Scores of Different Models on Different Datasets")
plt.grid(False)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
models = ["Model 1", "Model 2", "Model 3"]
parameters = ["Parameter 1", "Parameter 2", "Parameter 3"]
multadds = [[10, 20, 30], [20, 30, 40], [30, 40, 50]]

# Create grouped bar plot
plt.figure(figsize=(8, 6))
plt.bar(models, multadds[0], label="Parameter 1")
plt.bar(models, multadds[1], label="Parameter 2")
plt.bar(models, multadds[2], label="Parameter 3")

# Add labels and title
plt.xlabel("Model")
plt.ylabel("Multadds")
plt.title("Multadds of Different Models for Different Parameters")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bars
barWidth = 0.25

# set heights of bars
params = [11.69, 7.98, 1.25, 3.5, 7.39, 0.95, 0.54]
Multadds = [1.81, 2.83, 0.83, 0.3, 0.58, 0.2, 0.37]

# Set position of bar on X axis
r1 = np.arange(len(params))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(8, 6))

# Make the plot

# Make the plot
# plt.bar(r1, params, color='#7f6d5f', width=barWidth, 
plt.bar(r1, params, color='#7f6d5f', width=barWidth, edgecolor='white', label='Params in 10^6')
plt.bar(r2, Multadds, color='#557f2d', width=barWidth, edgecolor='white', label='Multadds in 10^9')

# Add xticks on the middle of the group bars
plt.xlabel('Model', fontweight='bold')

# Make the plot
plt.xticks([r + barWidth/2 for r in range(len(params))], ['ResNet', 'DenseNet', 'SqueezeNet', 'MobileNet', 'ShuffleNet', 'MobileViT', 'SqueezeViT'])

# Create legend & Show graphic
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools

# set width of bars
barWidth = 0.25

# set heights of bars
params = [11.69, 7.98, 1.25, 3.5, 7.39, 0.95, 0.54]
Multadds = [1.81, 2.83, 0.83, 0.3, 0.58, 0.2, 0.37]

# Set position of bar on X axis
r1 = np.arange(len(params))
r2 = [x + barWidth for x in r1]

fig, ax = plt.subplots(figsize=(8, 6))

# Make the plot for params
ax.bar(r1, params, color='#7f6d5f', width=barWidth, edgecolor='white', label='Params in 10^6')

# Create a second axes object that shares the same x-axis as the original axes object
ax2 = ax.twinx()

# Make the plot for mults
ax2.bar(r2, Multadds, color='#557f2d', width=barWidth, edgecolor='white', label='Multadds in 10^9')

# Add xticks on the middle of the group bars
ax.set_xlabel('Model', fontweight='bold')

# Make the plot
ax.set_xticks([r + barWidth/2 for r in range(len(params))])

# Add x-axis labels
ax.set_xticklabels(['ResNet', 'DenseNet', 'SqueezeNet', 'MobileNet', 'ShuffleNet', 'MobileViT', 'SqueezeViT'])
ax.set_ylabel('Params in 10^6')
ax2.set_ylabel('Multadds in 10^9')

# Create legend & Show graphic
ax.legend(bbox_to_anchor=(0.98,1))
ax2.legend(bbox_to_anchor=(1, 0.94))
# ax.grid(False)
# ax2.grid(False)
# fig.set_size_inches(8.33, 5.5)

fig.figsize=(3.28,2.33)
# Save the plot as a PDF
fig.savefig("../Plots/plot2_model_characteristics.pdf", bbox_inches="tight")
plt.show()

# %%
5.92/2.54
# Out:
# 2.3307086614173227

# %%
import numpy as np

# Split the table into rows and columns
rows = [
    ["ResNet", 0.742, 0.750, 0.807],
    ["DenseNet", 0.740, 0.770, 0.827],
    ["SqueezeNet", 0.730, 0.760, 0.674],
    ["MobileNet", 0.704, 0.743, 0.761],
    ["ShuffleNet", 0.702, 0.737, 0.771],
    ["MobileViT", 0.692, 0.746, 0.729],
    ["SqueezeViT", 0.733, 0.751, 0.809]
]

# Create four empty lists
model_names = []
y1 = []
y2 = []
y3 = []

# Iterate over the rows and add the values to the lists
for row in rows:
    model_names.append(row[0])
    y1.append(float(row[1]))
    y2.append(float(row[2]))
    y3.append(float(row[3]))

# Print the four lists
print("Model Names:", model_names)
print("Precision:", y1)
print("Recall:", y2)
print("F1 Score:", y3)
# Out:
# Model Names: ['ResNet', 'DenseNet', 'SqueezeNet', 'MobileNet', 'ShuffleNet', 'MobileViT', 'SqueezeViT']
# Precision: [0.742, 0.74, 0.73, 0.704, 0.702, 0.692, 0.733]
# Recall: [0.75, 0.77, 0.76, 0.743, 0.737, 0.746, 0.751]
# F1 Score: [0.807, 0.827, 0.674, 0.761, 0.771, 0.729, 0.809]

# %%
avg_multi = []
avg_binary = []

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = model_names
# y1 = np.array([0.9, 0.85, 0.92])
# y2 = np.array([0.88, 0.9, 0.86])
# y3 = np.array([0.95, 0.91, 0.93])

# Create line plot
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label="NIH",marker='o', markersize=5)
plt.plot(x, y2, label="Chexpert",marker='o', markersize=5)
plt.plot(x, y3, label="VinBig",marker='o', markersize=5)
plt.axhline(y1[-1], linestyle='dotted', color='black', alpha=1)
plt.axhline(y2[-1], linestyle='dotted', color='black', alpha=1)
plt.axhline(y3[-1], linestyle='dotted', color='black', alpha=1)

plt.grid(color='gray', alpha=0.2)
# Add labels and title
plt.xlabel("Model")
plt.ylabel("AUROC Score")
# plt.title("AUROC Scores of Different Models on Different Datasets")
plt.legend()
plt.savefig("../Plots/plot3_multilabel_auroc.pdf", bbox_inches="tight")
plt.show()

# %%
rows =[
    ["ResNet", 0.688, 0.849, 0.846],
    ["DenseNet", 0.700, 0.857, 0.864],
    ["SqueezeNet", 0.689, 0.850, 0.783],
    ["MobileNet", 0.672, 0.833, 0.800],
    ["ShuffleNet", 0.657, 0.828, 0.816],
    ["MobileViT (Baseline)", 0.664, 0.841, 0.757],
    ["SqueezeViT (Ours)", 0.703, 0.851, 0.815]
]
model_names = []
y4 = []
y5 = []
y6 = []

# Iterate over the rows and add the values to the lists
for row in rows:
    # model_names.append(row[0])
    y4.append(float(row[1]))
    y5.append(float(row[2]))
    y6.append(float(row[3]))

# Print the four lists
# print("Model Names:", model_names)
print("Precision:", y4)
print("Recall:", y5)
print("F1 Score:", y6)
# Out:
# Precision: [0.688, 0.7, 0.689, 0.672, 0.657, 0.664, 0.703]
# Recall: [0.849, 0.857, 0.85, 0.833, 0.828, 0.841, 0.851]
# F1 Score: [0.846, 0.864, 0.783, 0.8, 0.816, 0.757, 0.815]

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y4, label="NIH",marker='o', markersize=5)
plt.plot(x, y5, label="Chexpert",marker='o', markersize=5)
plt.plot(x, y6, label="VinBig",marker='o', markersize=5)
plt.axhline(y4[-1], linestyle='dotted', color='black', alpha=1)
plt.axhline(y5[-1], linestyle='dotted', color='black', alpha=1)
plt.axhline(y6[-1], linestyle='dotted', color='black', alpha=1)

plt.grid(color='gray', alpha=0.2)
# Add labels and title
plt.xlabel("Model")
plt.ylabel("AUROC Score")
# plt.title("AUROC Scores of Different Models on Different Datasets")
plt.legend()
plt.savefig("../Plots/plot4_binary_auroc.pdf", bbox_inches="tight")
plt.show()

# %%
avg_multi = []
avg_binary = []

# %%
for i in range(len(y1)):
    avg_multi.append((y1[i]+y2[i]+y3[i])/3)
    avg_binary.append((y4[i]+y5[i]+y6[i])/3)
len(avg_multi),len(avg_binary)
# Out:
# (7, 7)

# %%
# rows = [
#     [["ResNet", 0.742, 0.750, 0.807],
#     ["DenseNet", 0.740, 0.770, 0.827]],
#     [["SqueezeNet", 0.730, 0.760, 0.674],
#     ["MobileNet", 0.704, 0.743, 0.761],
#     ["ShuffleNet", 0.702, 0.737, 0.771]],
#     [["MobileViT", 0.692, 0.746, 0.729],
#     ["SqueezeViT", 0.733, 0.751, 0.809]]
# ]

# # Create four empty lists
# model_names = [[],[],[]]
# y1 = [[],[],[]]
# y2 = [[],[],[]]
# y3 = [[],[],[]]

# # Iterate over the rows and add the values to the lists
# for i in range(len(rows)):
#     for row in rows[i]:
#         model_names[i].append(row[0])
#         y1[i].append(float(row[1]))
#         y2[i].append(float(row[2]))
#         y3[i].append(float(row[3]))

# # Print the four lists
# print("Model Names:", model_names)
# print("Precision:", y1)
# print("Recall:", y2)
# print("F1 Score:", y3)

# %%
# x = model_names
# # y1 = np.array([0.9, 0.85, 0.92])
# # y2 = np.array([0.88, 0.9, 0.86])
# # y3 = np.array([0.95, 0.91, 0.93])

# # Create line plot
# plt.figure(figsize=(8, 6))
# plt.plot(x[0][0], y1[0][0], label="NIH",marker='o', markersize=5, color='blue')
# plt.plot(x[0][0], y2[0][0], label="Chexpert", color='orange',marker='o', markersize=5)
# plt.plot(x[0][0], y3[0][0], label="VinBig", color='green',marker='o', markersize=5)

# for i in range(len(x)):
#     plt.plot(x[i], y1[i],marker='o', markersize=5, color='blue')
#     plt.plot(x[i], y2[i],marker='o', markersize=5, color='orange')
#     plt.plot(x[i], y3[i],marker='o', markersize=5, color='green')
# # plt.plot(x[1], y3[1],marker='o', markersize=5,color='red')
# plt.axhline(y1[-1][-1], linestyle='dotted', color='black', alpha=1)
# plt.axhline(y2[-1][-1], linestyle='dotted', color='black', alpha=1)
# plt.axhline(y3[-1][-1], linestyle='dotted', color='black', alpha=1)

# plt.grid(color='gray', alpha=0.2)
# # Add labels and title
# plt.xlabel("Model")
# plt.ylabel("AUROC Score")
# # plt.title("AUROC Scores of Different Models on Different Datasets")
# plt.legend()
# plt.show()

# %%
df = pd.DataFrame(x,columns=['Model Name'])
df['avg_multi'] = avg_multi
df['avg_binary'] = avg_binary
df['params'] = params
df
# Out:
#    Model Name  avg_multi  avg_binary  params
# 0      ResNet   0.766333    0.794333   11.69
# 1    DenseNet   0.779000    0.807000    7.98
# 2  SqueezeNet   0.721333    0.774000    1.25
# 3   MobileNet   0.736000    0.768333    3.50
# 4  ShuffleNet   0.736667    0.767000    7.39
# 5   MobileViT   0.722333    0.754000    0.95
# 6  SqueezeViT   0.764333    0.789667    0.54

# %%
# set seaborn "whitegrid" theme
sns.set_style("darkgrid")

fig = plt.figure()
# use the scatterplot function
sns.scatterplot(data=df, x="avg_multi", y="avg_binary", size="params", hue="Model Name", edgecolors="black", alpha=0.5, sizes=(100, 500))

# Add titles (main and on axis)
plt.xlabel("Average Multi-label AUROC scores")
plt.ylabel("Average Binary AUROC scores")


# Locate the legend outside of the plot
# plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=17)

# show the graph
for i in range(len(df)):
    plt.text(df["avg_multi"][i], df["avg_binary"][i], str(df["Model Name"][i]), ha="left", va="center", fontsize=8)

# Locate the legend outside of the plot
plt.legend(bbox_to_anchor=(1, 1), loc="upper left", fontsize=10)
# plt.legend()
plt.show()
# fig = plt.figure()

# fig.savefig(filename, format='pdf')
fig.savefig("../Plots/plot1_intro.pdf", format='pdf', bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a list of average multilabel scores
avg_multilabel_scores = avg_multi

# Create a list of average binary scores
avg_binary_scores = avg_binary

# Create a scatter plot with the average multilabel scores on the x-axis and the average binary scores on the y-axis

colors = ["red", "green", "blue", "yellow", "purple", "cyan", "magenta"]
plt.scatter(avg_multilabel_scores, avg_binary_scores, s=[x*100 for x in params], alpha=0.7, c=colors)
# Create a scatter plot with the average multilabel scores on the x-axis and the average binary scores on the y-axis
# plt.scatter(avg_multilabel_scores, avg_binary_scores, s=avg_multilabel_scores * 100, alpha=0.8, c=colors)

# Add a legend to the plot
plt.legend(x, loc="upper left")
# Add a title and labels to the plot
plt.title("Average Multilabel vs. Average Binary Scores")
plt.xlabel("Average Multilabel Score")
plt.ylabel("Average Binary Score")

# Display the plot
plt.show()

# %%
import pandas as pd

# Create a list of lists to represent the table data
table_data = [
    ["ResNet", 0.688, 0.681, 0.580],
    ["DenseNet", 0.700, 0.690, 0.621],
    ["SqueezeNet", 0.689, 0.689, 0.564],
    ["MobileNet", 0.672, 0.634, 0.551],
    ["ShuffleNet", 0.657, 0.644, 0.585],
    ["MobileViT", 0.664, 0.652, 0.570],
    ["SqueezeViT", 0.703, 0.694, 0.595]
]

# Create a Pandas DataFrame from the list of lists
df = pd.DataFrame(table_data, columns=["Model", "NIH", "Chexpert", "VinBig"])

# type(df['NIH'][0])
list1 = []
list2 = []
for i in range(0,len(df["Model"])):
    list1.append(float(df['Chexpert'][i]) - float(df['NIH'][i]))
    list2.append(float(df['VinBig'][i]) - float(df['NIH'][i]))
# df['Chexpert - NIH'][i] = 
# df['VinBig - NIH'][i] = 
# Print the DataFrame
df = df.assign(chex_nih = list1)
NIH_pre = df.assign(vin_nih = list2)
print(NIH_pre)
# Out:
#         Model    NIH  Chexpert  VinBig  chex_nih  vin_nih
# 0      ResNet  0.688     0.681   0.580    -0.007   -0.108
# 1    DenseNet  0.700     0.690   0.621    -0.010   -0.079
# 2  SqueezeNet  0.689     0.689   0.564     0.000   -0.125
# 3   MobileNet  0.672     0.634   0.551    -0.038   -0.121
# 4  ShuffleNet  0.657     0.644   0.585    -0.013   -0.072
# 5   MobileViT  0.664     0.652   0.570    -0.012   -0.094
# 6  SqueezeViT  0.703     0.694   0.595    -0.009   -0.108

# %%
import seaborn as sns

# %%
df = NIH_pre[['chex_nih', 'vin_nih']]

# Set the color scheme and block size
cmap = sns.diverging_palette(220, 10, as_cmap=True)
block_size = 0.5

# Create the heatmap
sns.heatmap(df, annot=True, fmt=".3f", cmap=cmap, linewidths=0.5, linecolor="black", cbar=True)

# Set the title and labels
plt.title("Difference Between Chexpert and NIH AUROC Scores")
plt.xlabel("Model")
plt.ylabel("Difference (Chexpert - NIH)")

# Rotate the x labels to prevent overlapping
plt.xticks(rotation=45, ha="right")

# Display the plot
plt.show()
